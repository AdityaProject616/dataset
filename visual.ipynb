# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./Heart.csv')
df
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Age           0
# Sex           0
# ChestPain     0
# RestBP        0
# Chol          0
# Fbs           0
# RestECG       0
# MaxHR         0
# ExAng         0
# Oldpeak       0
# Slope         0
# Ca            4
# Thal          2
# AHD           0
# dtype: int64

# %%
df['Ca'].fillna(df.Ca.mean(),inplace=True)
df['Thal'].fillna(df.Ca.mode()[0],inplace=True)
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Age           0
# Sex           0
# ChestPain     0
# RestBP        0
# Chol          0
# Fbs           0
# RestECG       0
# MaxHR         0
# ExAng         0
# Oldpeak       0
# Slope         0
# Ca            0
# Thal          0
# AHD           0
# dtype: int64

# %%
sns.histplot(data=df,x='Age',kde=True, hue='Sex')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sns.scatterplot(data=df,x='Age',y="Chol",hue='ChestPain')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Chol'>

# %%
sns.barplot(data=df,x='ChestPain',y='Chol',hue='Sex')
# Out:
# <AxesSubplot:xlabel='ChestPain', ylabel='Chol'>

# %%
sns.lineplot(data=df,x='Age',y="Chol",hue='Sex')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Chol'>

# %%
male = df[df.Sex==1]
female = df[df.Sex==0]
male.shape
female.shape
# Out:
# (97, 15)

# %%
import matplotlib.pyplot as plt

# %%
plt.pie([male.shape[0],female.shape[0]],labels=['Male','Female'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7fcc04355c10>,
# ...
#  [Text(-0.5890242258008583, 0.9290050922463771, 'Male'),
#   Text(0.5890242258008579, -0.9290050922463774, 'Female')])

# %%
sns.boxplot(x='ChestPain',y='Chol',data=df)
# Out:
# <AxesSubplot:xlabel='ChestPain', ylabel='Chol'>

# %%
sns.boxplot(x='ChestPain',y='Chol',data=df)
sns.histplot(data=df,x='ChestPain')
sns.scatterplot(data=df,x='ChestPain',y='Chol')
# Out:
# <AxesSubplot:xlabel='ChestPain', ylabel='Chol'>

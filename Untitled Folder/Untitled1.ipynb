# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('./integrated_preprocessed_ds.csv')
df
# Out:
#      Unnamed: 0   age  sex  chest_pain  trestbps  cholestrol  fbs  restecg  \
# 0             0  63.0  1.0         1.0     145.0       233.0    1        2
# 1             1  67.0  1.0         4.0     160.0       286.0    0        2
# 2             2  67.0  1.0         4.0     120.0       229.0    0        2
# 3             3  37.0  1.0         3.0     130.0       250.0    0        0
# 4             4  41.0  0.0         2.0     130.0       204.0    0        2
# ..          ...   ...  ...         ...       ...         ...  ...      ...
# 715         289  52.0  1.0         4.0     160.0       331.0    0        0
# 716         290  54.0  0.0         3.0     130.0       294.0    0        1
# 717         291  56.0  1.0         4.0     155.0       342.0    1        0
# 718         292  58.0  0.0         2.0     180.0       393.0    0        0
# 719         293  65.0  1.0         4.0     130.0       275.0    0        1
#
#      thalach  exang  oldpeak  slope  ca  thal  num
# ...

# %% [markdown]
# df_target_0 = df[df['num']==0]
# df_target_0

# %%
# df_target_1 = df[df['num']==1]
# df_target_1

df.num = df.num.replace([2,3,4],1)
df.num.unique()
# Out:
# array([0, 1])

# %%
sns.scatterplot(data=df,x='age',y='cholestrol')
# Out:
# <AxesSubplot:xlabel='age', ylabel='cholestrol'>

# %%
target_0_mark = int(df_target_0.shape[0]*0.8)
target_1_mark = int(df_target_1.shape[0]*0.8)

# %%
train_data = pd.concat([
    df_target_0.iloc[:target_0_mark,:],
    df_target_1.iloc[:target_1_mark,:]
],axis=0)
train_data
# Out:
#      Unnamed: 0   age  sex  chest_pain  trestbps  cholestrol  fbs  restecg  \
# 0             0  63.0  1.0         1.0     145.0       233.0    1        2
# 3             3  37.0  1.0         3.0     130.0       250.0    0        0
# 4             4  41.0  0.0         2.0     130.0       204.0    0        2
# 5             5  56.0  1.0         2.0     120.0       236.0    0        0
# 7             7  57.0  0.0         4.0     120.0       354.0    0        0
# ..          ...   ...  ...         ...       ...         ...  ...      ...
# 656         230  45.0  1.0         4.0     130.0       219.0    0        1
# 657         231  46.0  1.0         4.0     120.0       231.0    0        0
# 658         232  46.0  1.0         4.0     130.0       222.0    0        0
# 659         233  48.0  1.0         4.0     122.0       275.0    1        1
# 660         234  48.0  1.0         4.0     160.0       193.0    0        0
#
#      thalach  exang  oldpeak  slope  ca  thal  num
# ...

# %%
test_data = pd.concat([
    df_target_0.iloc[target_0_mark:,:],
    df_target_1.iloc[target_1_mark:,:]
],axis=0)
test_data
# Out:
#      Unnamed: 0   age  sex  chest_pain  trestbps  cholestrol  fbs  restecg  \
# 542         116  51.0  0.0         2.0     160.0       194.0    0        0
# 543         117  51.0  0.0         3.0     110.0       190.0    0        0
# 544         118  51.0  0.0         3.0     130.0       220.0    0        0
# 545         119  51.0  0.0         3.0     150.0       200.0    0        0
# 546         120  51.0  1.0         2.0     125.0       188.0    0        0
# ..          ...   ...  ...         ...       ...         ...  ...      ...
# 715         289  52.0  1.0         4.0     160.0       331.0    0        0
# 716         290  54.0  0.0         3.0     130.0       294.0    0        1
# 717         291  56.0  1.0         4.0     155.0       342.0    1        0
# 718         292  58.0  0.0         2.0     180.0       393.0    0        0
# 719         293  65.0  1.0         4.0     130.0       275.0    0        1
#
#      thalach  exang  oldpeak  slope  ca  thal  num
# ...

# %% [markdown]
# # Logistic Regression

# %%
X = df.drop('num',axis=1)
y = df.num

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 715    1
# 716    1
# 717    1
# 718    1
# 719    1
# Name: num, Length: 720, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=0,test_size = 0.3)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# /home/aditya_m/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.score(X_test,y_test)
pred = model.predict(X_test)_

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_train,pred,normalize=False))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [42], in <cell line: 2>()
#       1 from sklearn.metrics import accuracy_score
# ----> 2 print(accuracy_score(y_train,pred,normalize=False))
#
# File ~/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:211, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     145 """Accuracy classification score.
#     146
#     147 In multilabel classification, this function computes subset accuracy:
#    (...)
#     207 0.5
#     208 """
#     210 # Compute accuracy for each possible representation
# --> 211 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     212 check_consistent_length(y_true, y_pred, sample_weight)
#     213 if y_type.startswith("multilabel"):
#
# File ~/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:84, in _check_targets(y_true, y_pred)
# ...

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,pred)
# Out:
# array([[93, 11,  1,  0,  0],
#        [19, 65,  4,  2,  0],
#        [ 3,  6,  1,  2,  0],
#        [ 0,  7,  0,  1,  0],
#        [ 0,  1,  0,  0,  0]])

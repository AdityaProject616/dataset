# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading the dataset
dataset = pd.read_csv("./dataset_Facebook.csv", sep=";")
dataset.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
dataset.shape
# Out:
# (500, 19)

# %%
dataset.describeibe(include="all")
# Out:
#         Page total likes   Type    Category  Post Month  Post Weekday  \
# count         500.000000    500  500.000000  500.000000    500.000000
# unique               NaN      4         NaN         NaN           NaN
# top                  NaN  Photo         NaN         NaN           NaN
# freq                 NaN    426         NaN         NaN           NaN
# mean       123194.176000    NaN    1.880000    7.038000      4.150000
# std         16272.813214    NaN    0.852675    3.307936      2.030701
# min         81370.000000    NaN    1.000000    1.000000      1.000000
# 25%        112676.000000    NaN    1.000000    4.000000      2.000000
# 50%        129600.000000    NaN    2.000000    7.000000      4.000000
# 75%        136393.000000    NaN    3.000000   10.000000      6.000000
# max        139441.000000    NaN    3.000000   12.000000      7.000000
#
#          Post Hour        Paid  Lifetime Post Total Reach  \
# count   500.000000  499.000000                  500.00000
# ...

# %%
dataset.dtypes
# Out:
# Page total likes                                                         int64
# Type                                                                    object
# Category                                                                 int64
# Post Month                                                               int64
# Post Weekday                                                             int64
# Post Hour                                                                int64
# Paid                                                                   float64
# Lifetime Post Total Reach                                                int64
# Lifetime Post Total Impressions                                          int64
# Lifetime Engaged Users                                                   int64
# Lifetime Post Consumers                                                  int64
# Lifetime Post Consumptions                                               int64
# ...

# %%
dataset = dataset.dropna()
dataset.shape
# Out:
# (495, 19)

# %%
dataset.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   0
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
dataset['Type'].unique()
# Out:
# array(['Photo', 'Status', 'Link', 'Video'], dtype=object)

# %%
psubset = dataset[dataset["Type"]=="Photo"]
psubset
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441  Photo         2          12             4          3
# 2              139441  Photo         3          12             3          3
# 3              139441  Photo         2          12             2         10
# 4              139441  Photo         2          12             2          3
# 6              139441  Photo         3          12             1          3
# ..                ...    ...       ...         ...           ...        ...
# 494             85093  Photo         3           1             7         10
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
#
# ...

# %%
psubset.transpose()
# Out:
#                                                        0       2       3    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo   Photo   Photo
# Category                                                 2       3       2
# Post Month                                              12      12      12
# Post Weekday                                             4       3       2
# Post Hour                                                3       3      10
# Paid                                                   0.0     0.0     1.0
# Lifetime Post Total Reach                             2752    2413   50128
# Lifetime Post Total Impressions                       5091    4373   87991
# Lifetime Engaged Users                                 178     177    2211
# Lifetime Post Consumers                                109     113     790
# ...

# %%
vsubset = dataset[dataset['Type']=='Video']
vsubset
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 29             138895  Video         1          12             4         11
# 55             138329  Video         1          11             6          2
# 71             137893  Video         1          11             5          3
# 74             137893  Video         1          11             3         11
# 183            134879  Video         1           9             2         10
# 243            130791  Video         1           7             3         11
# 277            126424  Video         1           6             2         13
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 29    1.0                      36208                            61262
# 55    1.0                      16416                            31950
# 71    1.0                     100768                           220447
# 74    0.0                      13544                            30235
# ...

# %%
v_p_merged = pd.merge(vsubset,psubset,on='Paid')
v_p_merged
# Out:
#       Page total likes_x Type_x  Category_x  Post Month_x  Post Weekday_x  \
# 0                 138895  Video           1            12               4
# 1                 138895  Video           1            12               4
# 2                 138895  Video           1            12               4
# 3                 138895  Video           1            12               4
# 4                 138895  Video           1            12               4
# ...                  ...    ...         ...           ...             ...
# 1377              126424  Video           1             6               2
# 1378              126424  Video           1             6               2
# 1379              126424  Video           1             6               2
# 1380              126424  Video           1             6               2
# 1381              126424  Video           1             6               2
#
#       Post Hour_x  Paid  Lifetime Post Total Reach_x  \
# ...

# %%
dataset.drop_duplicates(subset='Total Interactions').sort_values()
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 473             91116   Photo         3           2             2          4
# 476             86909   Photo         1           1             6         10
# 479             86909   Photo         3           1             5          4
# 480             86909   Photo         2           1             4         11
# 493             85093   Photo         3           1             1          2
#
# ...

# %%
dataset = dataset.sort_va('Total Interactions',inplace=True)
dataset.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [37], in <cell line: 1>()
# ----> 1 dataset = dataset.sort_values('Total Interactions',inplace=True)
#       2 dataset
#
# AttributeError: 'NoneType' object has no attribute 'sort_values'

# %%
melted = pd.melt(dataset,id_vars=['Total Interactions'],value_vars=['Category','Paid'])
melted
# Out:
#      Total Interactions  variable  value
# 0                   100  Category    2.0
# 1                   164  Category    2.0
# 2                    80  Category    3.0
# 3                  1777  Category    2.0
# 4                   393  Category    2.0
# ..                  ...       ...    ...
# 985                 176      Paid    0.0
# 986                  84      Paid    0.0
# 987                  75      Paid    0.0
# 988                 115      Paid    0.0
# 989                 136      Paid    0.0
#
# [990 rows x 3 columns]

# %%
melted.pivot(index='Total Interactions',columns='variable',values='value')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 melted.pivot(index='Total Interactions',columns='variable',values='value')
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:7876, in DataFrame.pivot(self, index, columns, values)
#    7871 @Substitution("")
#    7872 @Appender(_shared_docs["pivot"])
#    7873 def pivot(self, index=None, columns=None, values=None) -> DataFrame:
#    7874     from pandas.core.reshape.pivot import pivot
# -> 7876     return pivot(self, index=index, columns=columns, values=values)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/reshape/pivot.py:520, in pivot(data, index, columns, values)
#     518     else:
#     519         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# --> 520 return indexed.unstack(columns_listlike)
#
# ...
